# %%
import pandas as pd

# %%
f=pd.read_csv("/home/francesco/LCP_B/Project/Iris/iris.data",header=None)

# %%
df=pd.read_csv("/home/francesco/LCP_B/Project/Iris/iris.data",header=None, 
               names = ["S-length", "S-width", "P-length","P-width","label"])
#df.columns = ["S-length", "S-width", "P-length","P-width","label"]
df
# Out:
#      S-length  S-width  P-length  P-width           label
# 0         5.1      3.5       1.4      0.2     Iris-setosa
# 1         4.9      3.0       1.4      0.2     Iris-setosa
# 2         4.7      3.2       1.3      0.2     Iris-setosa
# 3         4.6      3.1       1.5      0.2     Iris-setosa
# 4         5.0      3.6       1.4      0.2     Iris-setosa
# ..        ...      ...       ...      ...             ...
# 145       6.7      3.0       5.2      2.3  Iris-virginica
# 146       6.3      2.5       5.0      1.9  Iris-virginica
# 147       6.5      3.0       5.2      2.0  Iris-virginica
# 148       6.2      3.4       5.4      2.3  Iris-virginica
# 149       5.9      3.0       5.1      1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
    q = QuantumRegister(N,'q') # Initialise quantum register
    x = ParameterVector('x', N) # actual input data
    
    circuit = QuantumCircuit(N)
    for i in range(N):
        circuit.h(q[i])
        circuit.rz(x[i],q[i])
    
    for i in range(0,N-1):
        circuit.cx(q[i],q[i+1])
        circuit.rz(x[i]*x[i+1], q[i+1])
        circuit.cx(q[i],q[i+1])

    return circuit

q = QuantumRegister(N,'q') # Initialise q    return circuit
 theta = ParameterVector('θ', 2*N)  # variational parameters
    
    circuit = QuantumCircuit(q)
    for i in range(N):
        circuit.ry(theta[i],q[i]) # first N parameters
        
    for i in range(N-1):
        circuit.cx(q[i],q[i+1])
        
    for i in range(N):

        circuit.ry(theta[i+N],q[i]) # last N
