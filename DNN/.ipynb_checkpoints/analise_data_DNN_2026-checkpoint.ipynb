# %% [markdown]
# # DNN: analysis with Keras of 2D data

# %% [markdown]
# # Keras Tuner
# check https://keras.io/keras_tuner/getting_started/ or just pip install keras-tuner -q
#
# install tensorflow

# %%
import numpy as np

from keras.models import Sequential
from keras.layers import Dense, Dropout

import matplotlib as mpl
import matplotlib.pyplot as plt
# default font
plt.rcParams['font.size'] = 13

from sklearn.preprocessing import StandardScaler

# %run useful.py

# training/validation/test fractions
perc_train = 0.7
perc_valid = 0.15
perc_test = 0.15
#  check it sums to 1 
assert abs(perc_train + perc_valid + perc_test - 1.0) < 1e-12
# Out:
# 2026-03-09 13:43:23.238055: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Read data

# %%
# Keras works with numpy arrays: just use them from the start

TYPE=4
# number of features per sample
L=8
# span of each component
B=10
x = np.loadtxt(filename("data",L,TYPE), delimiter=' ')
y = np.loadtxt(filename("labels",L,TYPE), delimiter=' ')
y = y.astype("int")
print(x.shape)
N = len(x)


# dim. of a sample
L = len(x[0])
print(L)

for i in range(5):
    print(x[i],y[i])

N_train = int(perc_train * N)
N_valid = int(perc_valid * N)
N_test = N - N_train - N_valid
print(f'data: {N}\ntrain: {N_train}\nvalid: {N_valid}\ntest: {N_test}')

plot_data(x,y)
# Out:
# (12000, 8)
# 8
# [1.83918812 2.04560279 5.67725029 5.95544703 9.6451452  6.53177097
#  7.48906638 6.53569871] 0
# [7.47714809 9.61306736 0.08388298 1.06444377 2.98703714 6.56411183
#  8.09812553 8.72175914] 0
# [9.64647597 7.23685347 6.42475328 7.17453621 4.67599007 3.25584678
#  4.39644606 7.29689083] 0
# [9.94014586 6.76873712 7.90822518 1.70914258 0.26849276 8.00370244
#  9.03722538 0.2467621 ] 0
# [4.91747318 5.26255167 5.9636601  0.51957545 8.95089528 7.2826618
#  8.18350011 5.00222753] 1
# data: 12000
# train: 8400
# valid: 1800
# test: 1800

# %% [markdown]
# ## Split data and standardize (fit on train only)

# %%
def Standardize(x,m,s):
    """
    rescale each component using its mean and standard deviation
    x: data points (numpy array)
    m: mean values (numpy array)
    s: standard deviations (numpy array)
    return: rescaled data points (numpy array)
    """
    N = len(x)
    # assuming len(m)=len(s)=len(x[0])
    mm,ss = np.tile(m,(N,1)), np.tile(s,(N,1))
    return (x-mm)/ss

# split data into train/validation/test sets and check 
(x_train, y_train) = (x[0:N_train],y[0:N_train])
(x_valid, y_valid) = (x[N_train:N_train+N_valid],y[N_train:N_train+N_valid])
(x_test, y_test) = (x[N_train+N_valid:],y[N_train+N_valid:])
print("Train:",len(x_train),"\t Validation:",len(x_valid),"\t Test:",len(x_test))


x_train_mean = np.mean(x_train, axis=0)
x_train_std = np.std(x_train, axis=0)
#print("train stats before rescaling:\nmean value=", x_train_mean, "\nstd. dev.=", x_train_std)

x_valid_mean = np.mean(x_valid, axis=0)
x_valid_std = np.std(x_valid, axis=0)
#print("validation stats before rescaling:\nmean value=", x_valid_mean, "\nstd. dev.=", x_valid_std)

x_test_mean = np.mean(x_test, axis=0)
x_test_std = np.std(x_test, axis=0)
#print("test stats before rescaling:\nmean value=", x_test_mean, "\nstd. dev.=", x_test_std)

x_train = Standardize(x_train, x_train_mean, x_train_std)
x_valid = Standardize(x_valid, x_valid_mean, x_valid_std)
x_test = Standardize(x_test, x_test_mean, x_test_std)
print("after rescaling (train):\nmean value=", x_train.mean(axis=0), "\nstd. dev.=", x_train.std(axis=0))
# Out:
# Train: 8400 	 Validation: 1800 	 Test: 1800
# after rescaling (train):
# mean value= [ 9.17572896e-16  1.18834043e-14 -1.95478554e-15 -3.53337069e-15
#  -6.42594443e-15 -2.40365928e-15 -2.88332932e-15 -8.27623684e-15]
# std. dev.= [1. 1. 1. 1. 1. 1. 1. 1.]

# %% [markdown]
# ## Define the model with Keras / Tensorflow

# %%
# reproducibility (?)
np.random.seed(12345)
import tensorflow.random as tf_r
tf_r.set_seed(12345)

# We use case 1
CASE=3

if CASE==1:
    # 3 inner layers
    model = Sequential()
    # input layer
    model.add(Dense(L,input_shape=(L,),activation='relu'))
    #inner layers
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.1))
    #outer layer
    model.add(Dense(1,activation='sigmoid'))
    nepoch=200
# as case 1 but one layer shorter
if CASE==2:
    # 2 inner layers
    model = Sequential()
    model.add(Dense(L,input_shape=(L,),activation='relu'))
    model.add(Dense(40,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation='sigmoid'))
    nepoch=200
#deeper
if CASE==3:
    # 4 inner layers
    model = Sequential()
    model.add(Dense(L,input_shape=(L,),activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(1,activation='sigmoid'))
    nepoch=200
    
print(model.summary())
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 10)             │            90 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 723 (2.82 KB)
#  Trainable params: 723 (2.82 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ## Optimization method and cost function

# %%
model.compile(loss='binary_crossentropy',
              optimizer='RMSprop',
              #optimizer='adam',
              metrics=['accuracy'])

# %% [markdown]
# ## Training

# %%
fit = model.fit(x_train, y_train,
               epochs = nepoch, batch_size = 50,
               validation_data=(x_valid,y_valid),
               verbose=2)
# Out:
# Epoch 1/200
# 168/168 - 2s - 13ms/step - accuracy: 0.4987 - loss: 0.6936 - val_accuracy: 0.5122 - val_loss: 0.6928
# Epoch 2/200
# 168/168 - 1s - 3ms/step - accuracy: 0.5174 - loss: 0.6923 - val_accuracy: 0.5083 - val_loss: 0.6921
# Epoch 3/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5277 - loss: 0.6913 - val_accuracy: 0.5139 - val_loss: 0.6917
# Epoch 4/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5304 - loss: 0.6906 - val_accuracy: 0.5100 - val_loss: 0.6913
# Epoch 5/200
# 168/168 - 1s - 3ms/step - accuracy: 0.5335 - loss: 0.6900 - val_accuracy: 0.5150 - val_loss: 0.6904
# Epoch 6/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5363 - loss: 0.6893 - val_accuracy: 0.5161 - val_loss: 0.6894
# Epoch 7/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5336 - loss: 0.6887 - val_accuracy: 0.5122 - val_loss: 0.6883
# Epoch 8/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5348 - loss: 0.6881 - val_accuracy: 0.5089 - val_loss: 0.6873
# Epoch 9/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5349 - loss: 0.6873 - val_accuracy: 0.5100 - val_loss: 0.6863
# Epoch 10/200
# 168/168 - 1s - 3ms/step - accuracy: 0.5319 - loss: 0.6864 - val_accuracy: 0.5233 - val_loss: 0.6850
# Epoch 11/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5373 - loss: 0.6852 - val_accuracy: 0.5211 - val_loss: 0.6835
# Epoch 12/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5363 - loss: 0.6839 - val_accuracy: 0.5333 - val_loss: 0.6822
# Epoch 13/200
# 168/168 - 1s - 3ms/step - accuracy: 0.5376 - loss: 0.6826 - val_accuracy: 0.5400 - val_loss: 0.6805
# Epoch 14/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5388 - loss: 0.6812 - val_accuracy: 0.5428 - val_loss: 0.6793
# Epoch 15/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5461 - loss: 0.6798 - val_accuracy: 0.5517 - val_loss: 0.6781
# Epoch 16/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5512 - loss: 0.6783 - val_accuracy: 0.5650 - val_loss: 0.6769
# Epoch 17/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5556 - loss: 0.6771 - val_accuracy: 0.5600 - val_loss: 0.6765
# Epoch 18/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5593 - loss: 0.6761 - val_accuracy: 0.5633 - val_loss: 0.6758
# Epoch 19/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5630 - loss: 0.6752 - val_accuracy: 0.5611 - val_loss: 0.6758
# Epoch 20/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5627 - loss: 0.6744 - val_accuracy: 0.5589 - val_loss: 0.6756
# Epoch 21/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5642 - loss: 0.6739 - val_accuracy: 0.5528 - val_loss: 0.6753
# Epoch 22/200
# 168/168 - 0s - 3ms/step - accuracy: 0.
200
# 168/168 - 0s - 3ms/step - accuracy: 0.5961 - loss: 0.6550 - val_accuracy: 0.5372 - val_loss: 0.6861
# Epoch 122/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5945 - loss: 0.6547 - val_accuracy: 0.5378 - val_loss: 0.6859
# Epoch 123/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5968 - loss: 0.6547 - val_accuracy: 0.5367 - val_loss: 0.6854
# Epoch 124/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5969 - loss: 0.6543 - val_accuracy: 0.5322 - val_loss: 0.6879
# Epoch 125/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5969 - loss: 0.6540 - val_accuracy: 0.5350 - val_loss: 0.6887
# Epoch 126/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5961 - loss: 0.6538 - val_accuracy: 0.5306 - val_loss: 0.6882
# Epoch 127/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5998 - loss: 0.6538 - val_accuracy: 0.5289 - val_loss: 0.6875
# Epoch 128/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5994 - loss: 0.6543 - val_accuracy: 0.5322 - val_loss: 0.6884
# Epoch 129/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5979 - loss: 0.6540 - val_accuracy: 0.5361 - val_loss: 0.6879
# Epoch 130/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5974 - loss: 0.6538 - val_accuracy: 0.5328 - val_loss: 0.6892
# Epoch 131/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5968 - loss: 0.6542 - val_accuracy: 0.5344 - val_loss: 0.6873
# Epoch 132/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5987 - loss: 0.6536 - val_accuracy: 0.5322 - val_loss: 0.6895
# Epoch 133/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5980 - loss: 0.6536 - val_accuracy: 0.5383 - val_loss: 0.6878
# Epoch 134/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5995 - loss: 0.6529 - val_accuracy: 0.5350 - val_loss: 0.6905
# Epoch 135/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5983 - loss: 0.6530 - val_accuracy: 0.5317 - val_loss: 0.6885
# Epoch 136/200

# %%
fig,AX=plt.subplots(1,2,figsize=(12,5.))
ax=AX[0]
ax.plot(fit.history['accuracy'],label="train",c="b",ls="--")
ax.plot(fit.history['val_accuracy'],label="valid.",c="r")
ax.set_xlabel('epoch')
ax.set_ylabel("Accuracy")
ax.legend()
ax=AX[1]
ax.plot(fit.history['loss'],label="train",c="b",ls="--")
ax.plot(fit.history['val_loss'],label="valid.",c="r")
ax.set_xlabel('epoch')
ax.set_ylabel("Loss")
ax.legend()

# %% [markdown]
# # Evaluation on the test set

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Final test loss: {test_loss:.4f}")
print(f"Final test accuracy: {test_acc:.4f}")
# Out:
# Final test loss: 0.5049
# Final test accuracy: 0.7628

# %% [markdown]
# ## Grid to show preditions

# %%
dX = .1
X1 = np.arange(0,10+dX, dX)
LG = len(X1)
# 2D meshgrid
X, Y = np.meshgrid(X1, X1)
allXY = np.reshape((np.array((X,Y)).T),(LG**2,2))
#create synthetic inputs with L features for each grid point; initialized randomly in [0, B].
grid = np.random.rand(LG**2,L)*B
#replace first 2 features with the actual 2D coordinates
grid[:,:2] = allXY
#standardize using train-set mean/std before prediction
grid_r=Standardize(grid,x_train_mean,x_train_std)

pred = model.predict(grid_r)

fig,AX=plt.subplots(1,3,figsize=(16,5.))
ax=AX[0]
ax.scatter(x[:,0],x[:,1],c=y,s=6)
ax.set_title("data")
ax=AX[1]
ax.pcolormesh(X1,X1,pred.reshape((LG, LG)))
ax.set_title("prediction $\\hat y$")
ax=AX[2]
pred01=np.copy(pred)
pred01[pred>0.5]=1
pred01[pred<=0.5]=0
ax.pcolormesh(X1,X1,pred01.reshape((LG, LG)))
ax.set_title("where $\\hat y > 1/2$")
plt.show()
print(f"remember: these are 2 out of L={L} dimensions, of which L-2 contain random noise")
# Out:
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# remember: these are 2 out of L=8 dimensions, of which L-2 contain random noise
