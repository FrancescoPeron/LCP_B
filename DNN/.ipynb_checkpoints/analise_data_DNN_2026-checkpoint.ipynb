# %% [markdown]
# # DNN: analysis with Keras of 2D data

# %% [markdown]
# # Keras Tuner
# check https://keras.io/keras_tuner/getting_started/ or just pip install keras-tuner -q
#
# install tensorflow

# %%
import numpy as np

from keras.models import Sequential
from keras.layers import Dense, Dropout

import matplotlib as mpl
import matplotlib.pyplot as plt
# default font
plt.rcParams['font.size'] = 13

from sklearn.preprocessing import StandardScaler

# %run useful.py

# training/validation/test fractions
perc_train = 0.7
perc_valid = 0.15
perc_test = 0.15
#  check it sums to 1 
assert abs(perc_train + perc_valid + perc_test - 1.0) < 1e-12

# %% [markdown]
# ## Read data

# %%
# Keras works with numpy arrays: just use them from the start

TYPE=4
# number of features per sample
L=8
# span of each component
B=10
x = np.loadtxt(filename("data",L,TYPE), delimiter=' ')
y = np.loadtxt(filename("labels",L,TYPE), delimiter=' ')
y = y.astype("int")
print(x.shape)
N = len(x)


# dim. of a sample
L = len(x[0])
print(L)

for i in range(5):
    print(x[i],y[i])

N_train = int(perc_train * N)
N_valid = int(perc_valid * N)
N_test = N - N_train - N_valid
print(f'data: {N}\ntrain: {N_train}\nvalid: {N_valid}\ntest: {N_test}')

plot_data(x,y)
# Out:
# (12000, 8)
# 8
# [1.83918812 2.04560279 5.67725029 5.95544703 9.6451452  6.53177097
#  7.48906638 6.53569871] 0
# [7.47714809 9.61306736 0.08388298 1.06444377 2.98703714 6.56411183
#  8.09812553 8.72175914] 0
# [9.64647597 7.23685347 6.42475328 7.17453621 4.67599007 3.25584678
#  4.39644606 7.29689083] 0
# [9.94014586 6.76873712 7.90822518 1.70914258 0.26849276 8.00370244
#  9.03722538 0.2467621 ] 0
# [4.91747318 5.26255167 5.9636601  0.51957545 8.95089528 7.2826618
#  8.18350011 5.00222753] 1
# data: 12000
# train: 8400
# valid: 1800
# test: 1800

# %% [markdown]
# ## Split data and standardize (fit on train only)

# %%
def Standardize(x,m,s):
    """
    rescale each component using its mean and standard deviation
    x: data points (numpy array)
    m: mean values (numpy array)
    s: standard deviations (numpy array)
    return: rescaled data points (numpy array)
    """
    N = len(x)
    # assuming len(m)=len(s)=len(x[0])
    mm,ss = np.tile(m,(N,1)), np.tile(s,(N,1))
    return (x-mm)/ss

# split data into train/validation/test sets and check 
(x_train, y_train) = (x[0:N_train],y[0:N_train])
(x_valid, y_valid) = (x[N_train:N_train+N_valid],y[N_train:N_train+N_valid])
(x_test, y_test) = (x[N_train+N_valid:],y[N_train+N_valid:])
print("Train:",len(x_train),"\t Validation:",len(x_valid),"\t Test:",len(x_test))


x_train_mean = np.mean(x_train, axis=0)
x_train_std = np.std(x_train, axis=0)
#print("train stats before rescaling:\nmean value=", x_train_mean, "\nstd. dev.=", x_train_std)

x_valid_mean = np.mean(x_valid, axis=0)
x_valid_std = np.std(x_valid, axis=0)
#print("validation stats before rescaling:\nmean value=", x_valid_mean, "\nstd. dev.=", x_valid_std)

x_test_mean = np.mean(x_test, axis=0)
x_test_std = np.std(x_test, axis=0)
#print("test stats before rescaling:\nmean value=", x_test_mean, "\nstd. dev.=", x_test_std)

x_train = Standardize(x_train, x_train_mean, x_train_std)
x_valid = Standardize(x_valid, x_valid_mean, x_valid_std)
x_test = Standardize(x_test, x_test_mean, x_test_std)
print("after rescaling (train):\nmean value=", x_train.mean(axis=0), "\nstd. dev.=", x_train.std(axis=0))
# Out:
# Train: 8400 	 Validation: 1800 	 Test: 1800
# after rescaling (train):
# mean value= [ 9.17572896e-16  1.18834043e-14 -1.95478554e-15 -3.53337069e-15
#  -6.42594443e-15 -2.40365928e-15 -2.88332932e-15 -8.27623684e-15]
# std. dev.= [1. 1. 1. 1. 1. 1. 1. 1.]

# %% [markdown]
# ## Define the model with Keras / Tensorflow

# %%
# reproducibility (?)
np.random.seed(12345)
import tensorflow.random as tf_r
tf_r.set_seed(12345)

# We use case 1
CASE=1

if CASE==1:
    # 3 inner layers
    model = Sequential()
    # input layer
    model.add(Dense(L,input_shape=(L,),activation='relu'))
    #inner layers
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.05))
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.05))
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.05))
    #outer layer
    model.add(Dense(1,activation='sigmoid'))
    nepoch=200
# as case 1 but one layer shorter
if CASE==2:
    # 2 inner layers
    model = Sequential()
    model.add(Dense(L,input_shape=(L,),activation='relu'))
    model.add(Dense(40,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation='sigmoid'))
    nepoch=200
#deeper
if CASE==3:
    # 4 inner layers
    model = Sequential()
    model.add(Dense(L,input_shape=(L,),activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(1,activation='sigmoid'))
    nepoch=200
    
print(model.summary())
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_56 (Dense)                │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_57 (Dense)                │ (None, 20)             │           180 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_28 (Dropout)            │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_58 (Dense)                │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_29 (Dropout)            │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_59 (Dense)                │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_30 (Dropout)            │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_60 (Dense)                │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,113 (4.35 KB)
#  Trainable params: 1,113 (4.35 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ## Optimization method and cost function

# %%
model.compile(loss='binary_crossentropy',
              optimizer='RMSprop',
              #optimizer='adam',
              metrics=['accuracy'])

# %% [markdown]
# ## Training

# %%
fit = model.fit(x_train, y_train,
               epochs = nepoch, batch_size = 50,
               validation_data=(x_valid,y_valid),
               verbose=2)
# Out:
# Epoch 1/200
# 168/168 - 2s - 10ms/step - accuracy: 0.5029 - loss: 0.6935 - val_accuracy: 0.5106 - val_loss: 0.6902
# Epoch 2/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5235 - loss: 0.6906 - val_accuracy: 0.5128 - val_loss: 0.6890
# Epoch 3/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5245 - loss: 0.6900 - val_accuracy: 0.5161 - val_loss: 0.6885
# Epoch 4/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5268 - loss: 0.6891 - val_accuracy: 0.5222 - val_loss: 0.6874
# Epoch 5/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5288 - loss: 0.6887 - val_accuracy: 0.5200 - val_loss: 0.6869
# Epoch 6/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5302 - loss: 0.6885 - val_accuracy: 0.5161 - val_loss: 0.6866
# Epoch 7/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5314 - loss: 0.6873 - val_accuracy: 0.5194 - val_loss: 0.6857
# Epoch 8/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5329 - loss: 0.6871 - val_accuracy: 0.5189 - val_loss: 0.6850
# Epoch 9/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5325 - loss: 0.6862 - val_accuracy: 0.5211 - val_loss: 0.6842
# Epoch 10/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5379 - loss: 0.6847 - val_accuracy: 0.5206 - val_loss: 0.6834
# Epoch 11/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5364 - loss: 0.6843 - val_accuracy: 0.5228 - val_loss: 0.6819
# Epoch 12/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5424 - loss: 0.6832 - val_accuracy: 0.5300 - val_loss: 0.6812
# Epoch 13/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5455 - loss: 0.6829 - val_accuracy: 0.5378 - val_loss: 0.6802
# Epoch 14/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5452 - loss: 0.6815 - val_accuracy: 0.5461 - val_loss: 0.6789
# Epoch 15/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5455 - loss: 0.6812 - val_accuracy: 0.5406 - val_loss: 0.6776
# Epoch 16/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5452 - loss: 0.6798 - val_accuracy: 0.5428 - val_loss: 0.6765
# Epoch 17/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5483 - loss: 0.6783 - val_accuracy: 0.5472 - val_loss: 0.6759
# Epoch 18/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5508 - loss: 0.6781 - val_accuracy: 0.5389 - val_loss: 0.6748
# Epoch 19/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5544 - loss: 0.6777 - val_accuracy: 0.5406 - val_loss: 0.6749
# Epoch 20/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5575 - loss: 0.6767 - val_accuracy: 0.5494 - val_loss: 0.6744
# Epoch 21/200
# 168/168 - 1s - 3ms/step - accuracy: 0.
200
# 168/168 - 0s - 3ms/step - accuracy: 0.8669 - loss: 0.3180 - val_accuracy: 0.9111 - val_loss: 0.2358
# Epoch 186/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8721 - loss: 0.3165 - val_accuracy: 0.9172 - val_loss: 0.2302
# Epoch 187/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8633 - loss: 0.3168 - val_accuracy: 0.9133 - val_loss: 0.2401
# Epoch 188/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8689 - loss: 0.3117 - val_accuracy: 0.9161 - val_loss: 0.2325
# Epoch 189/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8712 - loss: 0.3106 - val_accuracy: 0.9283 - val_loss: 0.2197
# Epoch 190/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8699 - loss: 0.3104 - val_accuracy: 0.9228 - val_loss: 0.2243
# Epoch 191/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8736 - loss: 0.3025 - val_accuracy: 0.9233 - val_loss: 0.2200
# Epoch 192/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8761 - loss: 0.3030 - val_accuracy: 0.9156 - val_loss: 0.2322
# Epoch 193/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8735 - loss: 0.3065 - val_accuracy: 0.9206 - val_loss: 0.2220
# Epoch 194/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8789 - loss: 0.2996 - val_accuracy: 0.9122 - val_loss: 0.2247
# Epoch 195/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8775 - loss: 0.3003 - val_accuracy: 0.9128 - val_loss: 0.2319
# Epoch 196/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8686 - loss: 0.3061 - val_accuracy: 0.9117 - val_loss: 0.2364
# Epoch 197/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8738 - loss: 0.3022 - val_accuracy: 0.9111 - val_loss: 0.2308
# Epoch 198/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8743 - loss: 0.3110 - val_accuracy: 0.9106 - val_loss: 0.2223
# Epoch 199/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8811 - loss: 0.2895 - val_accuracy: 0.9167 - val_loss: 0.2105
# Epoch 200/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8736 - loss: 0.2988 - val_accuracy: 0.9094 - val_loss: 0.2359

# %%
fig,AX=plt.subplots(1,2,figsize=(12,5.))
ax=AX[0]
ax.plot(fit.history['accuracy'],label="train",c="b",ls="--")
ax.plot(fit.history['val_accuracy'],label="valid.",c="r")
ax.set_xlabel('epoch')
ax.set_ylabel("Accuracy")
ax.legend()
ax=AX[1]
ax.plot(fit.history['loss'],label="train",c="b",ls="--")
ax.plot(fit.history['val_loss'],label="valid.",c="r")
ax.set_xlabel('epoch')
ax.set_ylabel("Loss")
ax.legend()

# %% [markdown]
# # Evaluation on the test set

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Final test loss: {test_loss:.4f}")
print(f"Final test accuracy: {test_acc:.4f}")
# Out:
# Final test loss: 0.2517
# Final test accuracy: 0.9044

# %% [markdown]
# ## Grid to show preditions

# %%
dX = .1
X1 = np.arange(0,10+dX, dX)
LG = len(X1)
# 2D meshgrid
X, Y = np.meshgrid(X1, X1)
allXY = np.reshape((np.array((X,Y)).T),(LG**2,2))
#create synthetic inputs with L features for each grid point; initialized randomly in [0, B].
grid = np.random.rand(LG**2,L)*B
#replace first 2 features with the actual 2D coordinates
grid[:,:2] = allXY
#standardize using train-set mean/std before prediction
grid_r=Standardize(grid,x_train_mean,x_train_std)

pred = model.predict(grid_r)

fig,AX=plt.subplots(1,3,figsize=(16,5.))
ax=AX[0]
ax.scatter(x[:,0],x[:,1],c=y,s=6)
ax.set_title("data")
ax=AX[1]
ax.pcolormesh(X1,X1,pred.reshape((LG, LG)))
ax.set_title("prediction $\\hat y$")
ax=AX[2]
pred01=np.copy(pred)
pred01[pred>0.5]=1
pred01[pred<=0.5]=0
ax.pcolormesh(X1,X1,pred01.reshape((LG, LG)))
ax.set_title("where $\\hat y > 1/2$")
plt.show()
print(f"remember: these are 2 out of L={L} dimensions, of which L-2 contain random noise")
# Out:
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# remember: these are 2 out of L=8 dimensions, of which L-2 contain random noise
